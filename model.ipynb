# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
import skimage
print(skimage.__version__)
# Out:
# 0.17.2

# %%
import skimage.color
import skimage.io
import skimage.feature
import skimage.transform

# %%
## load the data

# %%
data=pickle.load(open('data_animals.pickle','rb'))
data['description']
# Out:
# 'There are 20 classes of images where each image are of 80x80 dim and there are total of 2023 instances'

# %%
## split the data into independent and dependent set

# %%
X = data['data']
y = data['labels']

# %%
type(data)
# Out:
# dict

# %%
## split the data into train and test set

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2, stratify=y)

# %%
X_train.shape, X_test.shape, len(y_train), len(y_test)
# Out:
# ((1618, 80, 80, 3), (405, 80, 80, 3), 1618, 405)

# %% [markdown]
# ### Feature Extraction

# %% [markdown]
# ### HOG (Histogram Oriented Gradient)

# %% [markdown]
# # reading the image

# %%
img = skimage.io.imread('lion.bmp')
plt.figure(figsize=(6,10))
plt.imshow(img)

# %%
# convert image to grayscale

img_rescale = skimage.transform.rescale(img,1/3).reshape((302, 215))

gray = skimage.color.rgb2gray(img_rescale)


feature_vector, hog_img = skimage.feature.hog(gray,orientations=9,pixels_per_cell=(14,14),cells_per_block=(2,2),
                   visualize=True)
# Out:
# /Users/paras/.local/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: The behavior of rgb2gray will change in scikit-image 0.19. Currently, rgb2gray allows 2D grayscale image to be passed as inputs and leaves them unmodified as outputs. Starting from version 0.19, 2D arrays will be treated as 1D images with 3 channels.
#   """

# %%
img_rescale = skimage.transform.rescale(img,1/3)
img_rescale.shape
# Out:
# (302, 215, 1)

# %%
len(feature_vector)
# Out:
# 10080

# %%
img.shape
# Out:
# (907, 645, 3)

# %%
plt.figure(figsize=(12,8))

plt.subplot(1,2,1)
plt.imshow(gray,cmap='gray')
plt.subplot(1,2,2)
plt.imshow(hog_img,cmap='gray')

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# #### 1.RGB TO GRAYSCALE
# #### 2.HOG

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class rgb2gray_transform(BaseEstimator,TransformerMixin):
    import skimage.color
    def __init__(self):
        pass
    def fit(self,X,y=None):
        return self
    def transform(self,X,y=None):
        return np.array([skimage.color.rgb2gray(x) for x in X])

# %%
X_train.shape
# Out:
# (1618, 80, 80, 3)

# %%
rgb2gray_obj=rgb2gray_transform()
X_train_gray=rgb2gray_obj.fit_transform(X_train)

# %%
X_train_gray.shape
# Out:
# (1618, 80, 80)

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.imshow(X_train[0])
plt.subplot(1,2,2)
plt.imshow(X_train_gray[0],cmap='gray')

# %%
class hogtransformer(BaseEstimator,TransformerMixin):
    import skimage.feature
    def __init__(self,orientations=9,pixels_per_cell=(8,8),cells_per_block=(3, 3)):
        self.orientations=orientations
        self.pixels_per_cell=pixels_per_cell
        self.cells_per_block=cells_per_block
    
    def fit(self,X,y=None):
        return self
    def transform(self,X,y=None):
        def local_hog(img):
            hog_features= skimage.feature.hog(img,
                               orientations=self.orientations,
                               pixels_per_cell=self.pixels_per_cell,
                               cells_per_block=self.cells_per_block)
            return hog_features
        
        features = np.array([local_hog(x) for x in X])
#         hog_images= np.array([local_hog(x) for x in X])
        return features

# %%
# convert all grayscale images into hog images
hogt = hogtransformer()

# %%
X_train_hog=hogt.fit_transform(X_train_gray)

# %%
X_train_hog.shape
# Out:
# (1618, 5184)

# %% [markdown]
# ### Training Machine Learning Model

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler

# %%
model_sgd = SGDClassifier(loss='hinge',learning_rate='adaptive',early_stopping=True,eta0=0.1)

# %%
## pipeline 

X_train.shape, X_test.shape
# Out:
# ((1618, 80, 80, 3), (405, 80, 80, 3))

# %%
grayify = rgb2gray_transform()
hog_t = hogtransformer()
sc = StandardScaler()

# %%
## pipeline

## step1: convert to grayscale
X_train_gray = grayify.fit_transform(X_train)
## step2: extract features
X_train_hog=hog_t.fit_transform(X_train_gray)
## step3: perform normalization
X_train_scaled = sc.fit_transform(X_train_hog)
## step4: machine learning model
model_sgd.fit(X_train_scaled,y_train)
# Out:
# SGDClassifier(early_stopping=True, eta0=0.1, learning_rate='adaptive')

# %%
## step1: convert to grayscale
X_test_gray = grayify.fit_transform(X_test)
## step2: extract features
X_test_hog=hog_t.fit_transform(X_test_gray)
## step3: perform normalization
X_test_scaled = sc.transform(X_test_hog)

y_pred = model_sgd.predict(X_test_scaled)

# %% [markdown]
# ## model evaluation

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.5135802469135803

# %%
cr=metrics.classification_report(y_test,y_pred,output_dict=True)

# %%
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score    support
# bear           0.533333  0.400000  0.457143   20.00000
# cat            0.522727  0.718750  0.605263   32.00000
# chicken        0.642857  0.450000  0.529412   20.00000
# cow            0.400000  0.300000  0.342857   20.00000
# deer           0.611111  0.550000  0.578947   20.00000
# dog            0.307692  0.296296  0.301887   27.00000
# duck           0.666667  0.600000  0.631579   20.00000
# eagle          0.400000  0.210526  0.275862   19.00000
# elephant       0.578947  0.550000  0.564103   20.00000
# human          0.600000  0.900000  0.720000   20.00000
# lion           0.428571  0.315789  0.363636   19.00000
# monkey         0.500000  0.300000  0.375000   20.00000
# mouse          0.217391  0.250000  0.232558   20.00000
# natural        0.000000  0.000000  0.000000    2.00000
# panda          0.720000  0.782609  0.750000   23.00000
# pigeon         0.482759  0.700000  0.571429   20.00000
# rabbit         0.454545  0.500000  0.476190   20.00000
# sheep          0.521739  0.600000  0.558140   20.00000
# tiger          0.642857  0.782609  0.705882   23.00000
# wolf           0.529412  0.450000  0.486486   20.00000
# accuracy       0.513580  0.513580  0.513580    0.51358
# macro avg      0.488031  0.482829  0.476319  405.00000
# weighted avg   0.510861  0.513580  0.502795  405.00000

# %%
# if >0.5 it is a good model
metrics.cohen_kappa_score(y_test,y_pred)
# Out:
# 0.4857026828419302

# %%
### Pipelining the Model

# %%
from sklearn.pipeline import Pipeline

# %%
model_pipe = Pipeline([
    ('grayscale',rgb2gray_transform()),
    ('hog_transform',hogtransformer(orientations=8,pixels_per_cell=(10,10),cells_per_block=(3,3))),
    ('scaler',StandardScaler()),
    ('model_sgd',SGDClassifier(loss='hinge',learning_rate='adaptive',early_stopping=True,eta0=0.1))
])

# %%
model_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('grayscale', rgb2gray_transform()),
#                 ('hog_transform',
#                  hogtransformer(orientations=8, pixels_per_cell=(10, 10))),
#                 ('scaler', StandardScaler()),
#                 ('model_sgd',
#                  SGDClassifier(early_stopping=True, eta0=0.1,
#                                learning_rate='adaptive'))])

# %%
y_pred =model_pipe.predict(X_test)

# %%
y_pred
# Out:
# array(['eagle', 'eagle', 'panda', 'duck', 'rabbit', 'cat', 'mouse',
#        'mouse', 'bear', 'duck', 'elephant', 'sheep', 'cat', 'rabbit',
#        'wolf', 'monkey', 'rabbit', 'rabbit', 'cat', 'bear', 'sheep',
#        'mouse', 'duck', 'wolf', 'tiger', 'tiger', 'deer', 'rabbit',
#        'sheep', 'deer', 'monkey', 'rabbit', 'monkey', 'duck', 'cow',
#        'pigeon', 'cat', 'sheep', 'chicken', 'wolf', 'human', 'panda',
#        'human', 'lion', 'elephant', 'wolf', 'human', 'rabbit', 'wolf',
#        'elephant', 'tiger', 'dog', 'wolf', 'panda', 'duck', 'dog',
#        'human', 'lion', 'deer', 'elephant', 'tiger', 'mouse', 'panda',
#        'cow', 'deer', 'dog', 'bear', 'cow', 'duck', 'tiger', 'panda',
#        'elephant', 'rabbit', 'tiger', 'cow', 'chicken', 'human', 'mouse',
#        'dog', 'chicken', 'cat', 'rabbit', 'human', 'pigeon', 'sheep',
#        'duck', 'rabbit', 'eagle', 'deer', 'deer', 'panda', 'wolf',
#        'panda', 'wolf', 'monkey', 'duck', 'elephant', 'dog', 'pigeon',
#        'monkey', 'elephant', 'tiger', 'elephant', 'cow', 'duck', 'rabbit',
#        'dog', 'cow', 'wolf', 'chicken', 'cat', 'elephant', 'sheep', 'cat',
#        'duck', 'rabbit', 'sheep', 'eagle', 'elephant', 'human', 'duck',
#        'dog', 'tiger', 'cow', 'chicken', 'rabbit', 'elephant', 'lion',
#        'tiger', 'bear', 'tiger', 'cat', 'cat', 'lion', 'sheep', 'chicken',
#        'elephant', 'human', 'chicken', 'cat', 'wolf', 'bear', 'monkey',
#        'wolf', 'lion', 'tiger', 'cat', 'monkey', 'eagle', 'cat',
#        'chicken', 'eagle', 'monkey', 'deer', 'cow', 'eagle', 'deer',
#        'mouse', 'mouse', 'cat', 'panda', 'duck', 'dog', 'panda', 'lion',
#        'dog', 'eagle', 'deer', 'chicken', 'chicken', 'rabbit', 'dog',
#        'elephant', 'monkey', 'dog', 'elephant', 'sheep', 'duck', 'cow',
#        'cat', 'dog', 'mouse', 'elephant', 'tiger', 'panda', 'elephant',
#        'pigeon', 'tiger', 'tiger', 'bear', 'pigeon', 'mouse', 'pigeon',
#        'sheep', 'elephant', 'cow', 'monkey', 'deer', 'monkey', 'cow',
#        'cow', 'sheep', 'elephant', 'human', 'sheep', 'bear', 'duck',
#        'panda', 'panda', 'panda', 'human', 'human', 'bear', 'duck', 'cow',
#        'elephant', 'deer', 'deer', 'panda', 'tiger', 'sheep', 'mouse',
#        'pigeon', 'eagle', 'eagle', 'duck', 'deer', 'duck', 'duck',
#        'elephant', 'chicken', 'bear', 'cat', 'eagle', 'lion', 'elephant',
#        'cat', 'elephant', 'cow', 'tiger', 'dog', 'mouse', 'human', 'cat',
#        'panda', 'tiger', 'cat', 'rabbit', 'lion', 'tiger', 'duck',
#        'mouse', 'deer', 'monkey', 'tiger', 'dog', 'human', 'human', 'cat',
#        'chicken', 'lion', 'eagle', 'rabbit', 'panda', 'bear', 'human',
#        'rabbit', 'human', 'pigeon', 'sheep', 'deer', 'monkey', 'mouse',
#        'monkey', 'natural', 'deer', 'duck', 'dog', 'dog', 'mouse', 'cat',
#        'elephant', 'human', 'cow', 'sheep', 'human', 'pigeon', 'duck',
#        'pigeon', 'monkey', 'duck', 'monkey', 'human', 'cat', 'elephant',
#        'eagle', 'pigeon', 'duck', 'pigeon', 'chicken', 'wolf', 'cat',
#        'bear', 'pigeon', 'mouse', 'rabbit', 'wolf', 'human', 'deer',
#        'bear', 'wolf', 'eagle', 'sheep', 'rabbit', 'elephant', 'dog',
#        'cat', 'rabbit', 'cat', 'rabbit', 'cat', 'mouse', 'panda',
#        'rabbit', 'elephant', 'dog', 'eagle', 'tiger', 'deer', 'duck',
#        'duck', 'duck', 'elephant', 'tiger', 'lion', 'elephant', 'tiger',
#        'chicken', 'human', 'mouse', 'elephant', 'tiger', 'chicken',
#        'chicken', 'bear', 'elephant', 'lion', 'tiger', 'deer', 'wolf',
#        'pigeon', 'elephant', 'bear', 'bear', 'elephant', 'sheep',
#        'monkey', 'rabbit', 'deer', 'pigeon', 'mouse', 'panda', 'sheep',
#        'cow', 'wolf', 'sheep', 'bear', 'cow', 'deer', 'tiger', 'cat',
#        'eagle', 'human', 'eagle', 'sheep', 'tiger', 'monkey', 'cow',
#        'monkey', 'tiger', 'lion', 'elephant', 'mouse', 'panda', 'duck',
#        'dog', 'monkey', 'wolf', 'cow', 'pigeon', 'cat', 'eagle', 'pigeon',
#        'lion', 'chicken', 'eagle', 'human', 'panda', 'rabbit', 'sheep',
#        'chicken', 'tiger', 'lion', 'cat', 'panda'], dtype='<U8')

# %%
## evaluation

cr=pd.DataFrame(metrics.classification_report(y_test,y_pred,output_dict=True)).T
cr
# Out:
#               precision    recall  f1-score     support
# bear           0.500000  0.400000  0.444444   20.000000
# cat            0.642857  0.562500  0.600000   32.000000
# chicken        0.444444  0.400000  0.421053   20.000000
# cow            0.421053  0.400000  0.410256   20.000000
# deer           0.714286  0.750000  0.731707   20.000000
# dog            0.526316  0.370370  0.434783   27.000000
# duck           0.555556  0.750000  0.638298   20.000000
# eagle          0.526316  0.526316  0.526316   19.000000
# elephant       0.454545  0.750000  0.566038   20.000000
# human          0.782609  0.900000  0.837209   20.000000
# lion           0.428571  0.315789  0.363636   19.000000
# monkey         0.600000  0.600000  0.600000   20.000000
# mouse          0.315789  0.300000  0.307692   20.000000
# natural        0.000000  0.000000  0.000000    2.000000
# panda          0.714286  0.652174  0.681818   23.000000
# pigeon         0.529412  0.450000  0.486486   20.000000
# rabbit         0.333333  0.400000  0.363636   20.000000
# sheep          0.523810  0.550000  0.536585   20.000000
# tiger          0.678571  0.826087  0.745098   23.000000
# wolf           0.588235  0.500000  0.540541   20.000000
# accuracy       0.545679  0.545679  0.545679    0.545679
# macro avg      0.513999  0.520162  0.511780  405.000000
# weighted avg   0.543758  0.545679  0.539126  405.000000

# %%
# if >0.5 it is a good model
metrics.cohen_kappa_score(y_test,y_pred)
# Out:
# 0.5203398558187435

# %%
### Grid-search for hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV #FOR HYPERPARAMETER TUNING

# %%
base_estimator = Pipeline([
    ('grayscale',rgb2gray_transform()),
    ('hog_transform',hogtransformer()),
    ('scaler',StandardScaler()),
    ('model_sgd',SGDClassifier())
])

# %%
## parameters we need to tune

''' got error while including this in param_grid 
    
    {
        'hog_transform__orientations':[9,10],
        'hog_transform__pixels_per_cell':[(7,7),(8,8)],
        'hog_transform__cells_per_block':[(2,2),(3,3)],
        'model_sgd__loss':['hinge','squared_hinge'],
        'model_sgd__learning_rate':['adaptive'],
        'model_sgd__eta0': [0.0001,0.001]
    }
    '''

param_grid = [
    {
        'hog_transform__orientations':[9,10],
        'hog_transform__pixels_per_cell':[(7,7),(8,8)],
        'hog_transform__cells_per_block':[(2,2),(3,3)],
        'model_sgd__loss':['hinge','squared_hinge'],
        'model_sgd__learning_rate':['optimal'],
    }]

# %%
model_grid = GridSearchCV(estimator=base_estimator,param_grid=param_grid, scoring='accuracy',n_jobs=1,
                         cv=3,verbose=2)

# %%
model_grid.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   8.7s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   9.0s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=  10.2s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  17.1s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  13.2s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   9.7s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   8.2s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   8.2s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   8.1s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   8.5s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   8.5s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   8.3s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   9.7s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=  10.8s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=  12.7s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  10.7s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  11.5s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  10.3s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   8.9s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   8.8s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   9.2s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  10.1s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   9.1s
# [CV] END hog_transform__cells_per_block=(2, 2), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   8.2s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=  10.6s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=  10.5s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=  10.7s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  11.2s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  10.6s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  10.7s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   9.0s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   8.9s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   8.6s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   8.3s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   7.8s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=9, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   8.0s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   9.4s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   9.8s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=  10.3s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  11.4s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  10.6s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(7, 7), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=  10.5s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   8.6s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   8.9s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=hinge; total time=   7.9s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   7.8s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   7.8s
# [CV] END hog_transform__cells_per_block=(3, 3), hog_transform__orientations=10, hog_transform__pixels_per_cell=(8, 8), model_sgd__learning_rate=optimal, model_sgd__loss=squared_hinge; total time=   8.8s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('grayscale', rgb2gray_transform()),
#                                        ('hog_transform', hogtransformer()),
#                                        ('scaler', StandardScaler()),
#                                        ('model_sgd', SGDClassifier())]),
#              n_jobs=1,
#              param_grid=[{'hog_transform__cells_per_block': [(2, 2), (3, 3)],
#                           'hog_transform__orientations': [9, 10],
#                           'hog_transform__pixels_per_cell': [(7, 7), (8, 8)],
#                           'model_sgd__learning_rate': ['optimal'],
#                           'model_sgd__loss': ['hinge', 'squared_hinge']}],
#              scoring='accuracy', verbose=2)

# %%
model_grid.best_params_
# Out:
# {'hog_transform__cells_per_block': (2, 2),
#  'hog_transform__orientations': 9,
#  'hog_transform__pixels_per_cell': (8, 8),
#  'model_sgd__learning_rate': 'optimal',
#  'model_sgd__loss': 'squared_hinge'}

# %%
model_grid.best_score_
# Out:
# 0.7373508325889279

# %%
model_best = model_grid.best_estimator_

# %%
model_best
# Out:
# Pipeline(steps=[('grayscale', rgb2gray_transform()),
#                 ('hog_transform', hogtransformer(cells_per_block=(2, 2))),
#                 ('scaler', StandardScaler()),
#                 ('model_sgd', SGDClassifier(loss='squared_hinge'))])

# %%
model_best.get_params()
# Out:
# {'memory': None,
#  'steps': [('grayscale', rgb2gray_transform()),
#   ('hog_transform', hogtransformer(cells_per_block=(2, 2))),
#   ('scaler', StandardScaler()),
#   ('model_sgd', SGDClassifier(loss='squared_hinge'))],
#  'verbose': False,
#  'grayscale': rgb2gray_transform(),
#  'hog_transform': hogtransformer(cells_per_block=(2, 2)),
#  'scaler': StandardScaler(),
#  'model_sgd': SGDClassifier(loss='squared_hinge'),
#  'hog_transform__cells_per_block': (2, 2),
#  'hog_transform__orientations': 9,
#  'hog_transform__pixels_per_cell': (8, 8),
#  'scaler__copy': True,
#  'scaler__with_mean': True,
#  'scaler__with_std': True,
#  'model_sgd__alpha': 0.0001,
#  'model_sgd__average': False,
#  'model_sgd__class_weight': None,
#  'model_sgd__early_stopping': False,
#  'model_sgd__epsilon': 0.1,
#  'model_sgd__eta0': 0.0,
#  'model_sgd__fit_intercept': True,
#  'model_sgd__l1_ratio': 0.15,
#  'model_sgd__learning_rate': 'optimal',
#  'model_sgd__loss': 'squared_hinge',
#  'model_sgd__max_iter': 1000,
#  'model_sgd__n_iter_no_change': 5,
#  'model_sgd__n_jobs': None,
#  'model_sgd__penalty': 'l2',
#  'model_sgd__power_t': 0.5,
#  'model_sgd__random_state': None,
#  'model_sgd__shuffle': True,
#  'model_sgd__tol': 0.001,
#  'model_sgd__validation_fraction': 0.1,
#  'model_sgd__verbose': 0,
#  'model_sgd__warm_start': False}

# %%
y_pred = model_best.predict(X_test)

# %%
cr = pd.DataFrame(metrics.classification_report(y_test,y_pred,output_dict=True)).T
cr
# Out:
# /Users/paras/opt/anaconda3/envs/imgenv/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/paras/opt/anaconda3/envs/imgenv/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/paras/opt/anaconda3/envs/imgenv/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score     support
# bear           0.652174  0.750000  0.697674   20.000000
# cat            0.800000  0.875000  0.835821   32.000000
# chicken        0.875000  0.700000  0.777778   20.000000
# cow            0.576923  0.750000  0.652174   20.000000
# deer           0.818182  0.900000  0.857143   20.000000
# dog            0.416667  0.370370  0.392157   27.000000
# duck           0.727273  0.800000  0.761905   20.000000
# eagle          0.478261  0.578947  0.523810   19.000000
# elephant       0.681818  0.750000  0.714286   20.000000
# human          0.950000  0.950000  0.950000   20.000000
# lion           0.764706  0.684211  0.722222   19.000000
# monkey         0.666667  0.700000  0.682927   20.000000
# mouse          0.647059  0.550000  0.594595   20.000000
# natural        0.000000  0.000000  0.000000    2.000000
# panda          0.833333  0.869565  0.851064   23.000000
# pigeon         0.823529  0.700000  0.756757   20.000000
# rabbit         0.666667  0.600000  0.631579   20.000000
# sheep          0.750000  0.600000  0.666667   20.000000
# tiger          0.782609  0.782609  0.782609   23.000000
# wolf           0.842105  0.800000  0.820513   20.000000
# accuracy       0.718519  0.718519  0.718519    0.718519
# macro avg      0.687649  0.685535  0.683584  405.000000
# weighted avg   0.718965  0.718519  0.715712  405.000000

# %%
with open('best_model.pickle', 'wb') as f:
    pickle.dump(model_best, f)

# %%
from sklearn.pipeline import make_pipeline

# %%
pipeline1 = make_pipeline(rgb2gray_transform(),
                         hogtransformer(orientations=10,
                                       pixels_per_cell=(8,8),
                                        cells_per_block=(3,3)
                                       ))

# %%
feature_vector = pipeline1.fit_transform(X_train)

# %% [markdown]
# ## applying standard scaler

# %%
scaler = StandardScaler()
X_train_scaled=scaler.fit_transform(feature_vector)

# %%
model = SGDClassifier(learning_rate='optimal',loss='squared_hinge',alpha=0.01, early_stopping=True)

# %%
model.fit(X_train_scaled,y_train)
# Out:
# SGDClassifier(alpha=0.01, early_stopping=True, loss='squared_hinge')

# %% [markdown]
# ## evaluate model

# %%
f_v = pipeline1.fit_transform(X_test)
transformed_x = scaler.transform(f_v)
y_pred = model.predict(transformed_x)

# %%
cr=pd.DataFrame(metrics.classification_report(y_test,y_pred,output_dict=True)).T
# Out:
# /Users/paras/opt/anaconda3/envs/imgenv/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/paras/opt/anaconda3/envs/imgenv/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/paras/opt/anaconda3/envs/imgenv/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cr
# Out:
#               precision    recall  f1-score     support
# bear           0.608696  0.700000  0.651163   20.000000
# cat            0.783784  0.906250  0.840580   32.000000
# chicken        0.833333  0.750000  0.789474   20.000000
# cow            0.631579  0.600000  0.615385   20.000000
# deer           0.875000  0.700000  0.777778   20.000000
# dog            0.478261  0.407407  0.440000   27.000000
# duck           0.592593  0.800000  0.680851   20.000000
# eagle          0.578947  0.578947  0.578947   19.000000
# elephant       0.850000  0.850000  0.850000   20.000000
# human          0.894737  0.850000  0.871795   20.000000
# lion           0.636364  0.736842  0.682927   19.000000
# monkey         0.722222  0.650000  0.684211   20.000000
# mouse          0.687500  0.550000  0.611111   20.000000
# natural        0.000000  0.000000  0.000000    2.000000
# panda          0.833333  0.869565  0.851064   23.000000
# pigeon         0.789474  0.750000  0.769231   20.000000
# rabbit         0.625000  0.500000  0.555556   20.000000
# sheep          0.576923  0.750000  0.652174   20.000000
# tiger          0.750000  0.782609  0.765957   23.000000
# wolf           0.736842  0.700000  0.717949   20.000000
# accuracy       0.706173  0.706173  0.706173    0.706173
# macro avg      0.674229  0.671581  0.669308  405.000000
# weighted avg   0.706123  0.706173  0.702418  405.000000

# %% [markdown]
# ### save the model

# %%
pickle.dump(model,open('image_classification_sgd.pickle','wb'))

# %%
pickle.dump(scaler,open('dsa_scaler.pickle','wb'))
